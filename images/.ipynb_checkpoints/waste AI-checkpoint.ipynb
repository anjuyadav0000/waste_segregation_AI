# %%
import tensorflow as tf
from tensorflow.keras.preprocessing.image import ImageDataGenerator
from tensorflow.keras import layers, models
import os

# %%
dataset_path = "dataset/dataset-resized"

# %%
img_size = (128, 128)
batch_size = 32

datagen = ImageDataGenerator(
    rescale=1./255,
    validation_split=0.2   # 80% train, 20% validation
)

train_data = datagen.flow_from_directory(
    dataset_path,
    target_size=img_size,
    batch_size=batch_size,
    class_mode='categorical',
    subset='training'
)

val_data = datagen.flow_from_directory(
    dataset_path,
    target_size=img_size,
    batch_size=batch_size,
    class_mode='categorical',
    subset='validation'
)
# Out:
# Found 2024 images belonging to 6 classes.
# Found 503 images belonging to 6 classes.

# %%
from tensorflow.keras.applications import MobileNetV2
from tensorflow.keras import layers, models

base_model = MobileNetV2(
    input_shape=(128,128,3),
    include_top=False,
    weights="imagenet"
)

base_model.trainable = False

model = models.Sequential([
    base_model,

    layers.GlobalAveragePooling2D(),

    layers.Dropout(0.3),

    layers.Dense(
        train_data.num_classes,
        activation="softmax"
    )
])
# Out:
# C:\Users\suman\anaconda3\Lib\site-packages\keras\src\layers\convolutional\base_conv.py:113: UserWarning: Do not pass an `input_shape`/`input_dim` argument to a layer. When using Sequential models, prefer using an `Input(shape)` object as the first layer in the model instead.
#   super().__init__(activity_regularizer=activity_regularizer, **kwargs)

# %%
model.compile(
    optimizer='adam',
    loss='categorical_crossentropy',
    metrics=['accuracy']
)

# %%
history = model.fit(
    train_data,
    validation_data=val_data,
    epochs=25
)
# Out:
# Epoch 1/25
# 64/64 ━━━━━━━━━━━━━━━━━━━━ 19s 256ms/step - accuracy: 0.3286 - loss: 1.5986 - val_accuracy: 0.4294 - val_loss: 1.4756
# Epoch 2/25
# 64/64 ━━━━━━━━━━━━━━━━━━━━ 13s 204ms/step - accuracy: 0.5005 - loss: 1.2813 - val_accuracy: 0.4712 - val_loss: 1.3717
# Epoch 3/25
# 64/64 ━━━━━━━━━━━━━━━━━━━━ 21s 326ms/step - accuracy: 0.5420 - loss: 1.1939 - val_accuracy: 0.4732 - val_loss: 1.3485
# Epoch 4/25
# 64/64 ━━━━━━━━━━━━━━━━━━━━ 20s 310ms/step - accuracy: 0.5899 - loss: 1.0693 - val_accuracy: 0.4811 - val_loss: 1.3495
# Epoch 5/25
# 64/64 ━━━━━━━━━━━━━━━━━━━━ 16s 251ms/step - accuracy: 0.6418 - loss: 0.9638 - val_accuracy: 0.5149 - val_loss: 1.4114
# Epoch 6/25
# 64/64 ━━━━━━━━━━━━━━━━━━━━ 14s 218ms/step - accuracy: 0.6848 - loss: 0.8536 - val_accuracy: 0.4950 - val_loss: 1.3530
# Epoch 7/25
# 64/64 ━━━━━━━━━━━━━━━━━━━━ 21s 331ms/step - accuracy: 0.7238 - loss: 0.7695 - val_accuracy: 0.5249 - val_loss: 1.3678
# Epoch 8/25
# 64/64 ━━━━━━━━━━━━━━━━━━━━ 20s 306ms/step - accuracy: 0.7446 - loss: 0.7143 - val_accuracy: 0.5547 - val_loss: 1.3861
# Epoch 9/25
# 64/64 ━━━━━━━━━━━━━━━━━━━━ 21s 324ms/step - accuracy: 0.7866 - loss: 0.6007 - val_accuracy: 0.5606 - val_loss: 1.3102
# Epoch 10/25
# 64/64 ━━━━━━━━━━━━━━━━━━━━ 16s 248ms/step - accuracy: 0.8073 - loss: 0.5237 - val_accuracy: 0.5567 - val_loss: 1.3712
# Epoch 11/25
# 64/64 ━━━━━━━━━━━━━━━━━━━━ 19s 298ms/step - accuracy: 0.8365 - loss: 0.4567 - val_accuracy: 0.5746 - val_loss: 1.4992
# Epoch 12/25
# 64/64 ━━━━━━━━━━━━━━━━━━━━ 16s 249ms/step - accuracy: 0.8607 - loss: 0.3963 - val_accuracy: 0.5467 - val_loss: 1.6051
# Epoch 13/25
# 64/64 ━━━━━━━━━━━━━━━━━━━━ 21s 328ms/step - accuracy: 0.8844 - loss: 0.3300 - val_accuracy: 0.6004 - val_loss: 1.5233
# Epoch 14/25
# 64/64 ━━━━━━━━━━━━━━━━━━━━ 16s 248ms/step - accuracy: 0.8987 - loss: 0.3031 - val_accuracy: 0.5785 - val_loss: 1.8103
# Epoch 15/25
# 64/64 ━━━━━━━━━━━━━━━━━━━━ 13s 209ms/step - accuracy: 0.9002 - loss: 0.2863 - val_accuracy: 0.5268 - val_loss: 2.0822
# Epoch 16/25
# 64/64 ━━━━━━━━━━━━━━━━━━━━ 14s 216ms/step - accuracy: 0.9076 - loss: 0.2523 - val_accuracy: 0.5606 - val_loss: 1.7436
# Epoch 17/25
# 64/64 ━━━━━━━━━━━━━━━━━━━━ 21s 329ms/step - accuracy: 0.9175 - loss: 0.2215 - val_accuracy: 0.5726 - val_loss: 1.9658
# Epoch 18/25
# 64/64 ━━━━━━━━━━━━━━━━━━━━ 14s 223ms/step - accuracy: 0.9279 - loss: 0.2165 - val_accuracy: 0.5726 - val_loss: 1.9024
# Epoch 19/25
# 64/64 ━━━━━━━━━━━━━━━━━━━━ 20s 310ms/step - accuracy: 0.9373 - loss: 0.1764 - val_accuracy: 0.5507 - val_loss: 2.1057
# Epoch 20/25
# 64/64 ━━━━━━━━━━━━━━━━━━━━ 17s 260ms/step - accuracy: 0.9358 - loss: 0.1858 - val_accuracy: 0.5507 - val_loss: 1.9758
# Epoch 21/25
# 64/64 ━━━━━━━━━━━━━━━━━━━━ 22s 351ms/step - accuracy: 0.9541 - loss: 0.1332 - val_accuracy: 0.5308 - val_loss: 2.5454
# Epoch 22/25
# 64/64 ━━━━━━━━━━━━━━━━━━━━ 15s 226ms/step - accuracy: 0.9491 - loss: 0.1560 - val_accuracy: 0.5388 - val_loss: 2.3371
# Epoch 23/25
# 64/64 ━━━━━━━━━━━━━━━━━━━━ 14s 221ms/step - accuracy: 0.9590 - loss: 0.1375 - val_accuracy: 0.5825 - val_loss: 2.1185
# Epoch 24/25
# 64/64 ━━━━━━━━━━━━━━━━━━━━ 21s 324ms/step - accuracy: 0.9570 - loss: 0.1283 - val_accuracy: 0.5527 - val_loss: 2.3510
# Epoch 25/25
# 64/64 ━━━━━━━━━━━━━━━━━━━━ 15s 234ms/step - accuracy: 0.9649 - loss: 0.1192 - val_accuracy: 0.5606 - val_loss: 2.4143

# %%
converter = tf.lite.TFLiteConverter.from_keras_model(model)

# Compression ON
converter.optimizations = [tf.lite.Optimize.DEFAULT]

tflite_model = converter.convert()

with open("waste_model.tflite", "wb") as f:
    f.write(tflite_model)
# Out:
# INFO:tensorflow:Assets written to: C:\Users\suman\AppData\Local\Temp\tmp8knhcg9u\assets
# INFO:tensorflow:Assets written to: C:\Users\suman\AppData\Local\Temp\tmp8knhcg9u\assets
# Saved artifact at 'C:\Users\suman\AppData\Local\Temp\tmp8knhcg9u'. The following endpoints are available:
#
# * Endpoint 'serve'
#   args_0 (POSITIONAL_ONLY): TensorSpec(shape=(None, 128, 128, 3), dtype=tf.float32, name='keras_tensor_18')
# Output Type:
#   TensorSpec(shape=(None, 6), dtype=tf.float32, name=None)
# Captures:
#   2028356411536: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   2028356408080: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   2028356409616: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   2028356405776: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   2028356410192: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   2028356412880: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   2028356413072: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   2028356414032: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   2028356410576: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   2028356413840: TensorSpec(shape=(), dtype=tf.resource, name=None)

# %%
size = os.path.getsize("waste_model.tflite") / (1024 * 1024)
print(f"Model size: {size:.2f} MB")
# Out:
# Model size: 3.17 MB

# %%
 import plotly.express as px

# %%
print(train_data.class_indices)
# Out:
# {'cardboard': 0, 'glass': 1, 'metal': 2, 'paper': 3, 'plastic': 4, 'trash': 5}
